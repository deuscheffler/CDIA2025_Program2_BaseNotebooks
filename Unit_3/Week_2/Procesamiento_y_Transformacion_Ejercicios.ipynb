# %% [markdown]
# # Procesamiento y Transformación de Datos en Python
#
# ## Cuaderno de Ejercicios
#
# > Resuelve en conjunto con tu profesor. Escribe tu solución en la celda de código que aparece debajo de cada enunciado.

# %% [markdown]
# ## Transformación de Datos:

# %%
import pandas

# %%
import pandas as pd
import numpy as np

# %%
data= pd.DataFrame({"K1": [ "one", "two"] * 3 + [ "two"], "k2": [1, 1, 2, 3, 3, 4, 4]})

# %%
data.drop_duplicates()
# Out:
#     K1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data['k2'].replace([3], [5], inplace=True)
display(data)
# Out:
# C:\Users\Jefferson Dell\AppData\Local\Temp\ipykernel_40324\4084606751.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['k2'].replace([3], [5], inplace=True)
#     K1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   5
# 4  one   5
# 5  two   4
# 6  two   4

# %%
data_iris= pd.read_csv("Iris.csv")
display(data_iris.head())

data_iris.drop('Id', inplace=True, axis=1)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
display(data_iris.head())
data_iris['Species_cod']= data_iris["Species"].astype('category').cat.codes
display(data_iris.sample(5))
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species  \
# 9             4.9           3.1            1.5           0.1      Iris-setosa
# 58            6.6           2.9            4.6           1.3  Iris-versicolor
# 40            5.0           3.5            1.3           0.3      Iris-setosa
# 78            6.0           2.9            4.5           1.5  Iris-versicolor
# 34            4.9           3.1            1.5           0.1      Iris-setosa
#
#     Species_cod
# 9             0
# 58            1
# ...

# %%
def minmax(col):
    return round(col - col.min()) / (col.max() - col.min(), 4)

# %%
def zscore(col):
    return round((col - col.mean()) / col.std(), 4)

# %%
display(data_iris.head())

iris_norm= data_iris.copy()
iris_norm=iris_norm.apply(minmax, axis=0)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Species_cod
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Jefferson Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# ...

# %%
df= pd.read_csv("titanic.csv")
display(df.head())
# Out:
#   PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 0  1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# 1  2,1,1,"Cumings, Mrs. John Bradley (Florence Br...
# 2  3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...
# 3  4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...
# 4  5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...

# %%
df=df[['Survived', 'Pclass', 'Sex','Age', 'Embarked']]
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df=df[['Survived', 'Pclass', 'Sex','Age', 'Embarked']]
#       2 df.sample(5)
#
# File c:\Users\Jefferson Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Jefferson Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %% [markdown]
# ## Conversión de Tipos de Datos en Pandas

# %% [markdown]
# ## One Hot Encoding con Pandas

# %% [markdown]
# ### Escalamiento de Datos con NumPy y Pandas

# %% [markdown]
# ## Ejemplo práctico: Clasificación con preprocesamiento y One Hot Encoding
